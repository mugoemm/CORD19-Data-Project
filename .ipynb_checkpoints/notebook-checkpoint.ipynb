MB 1.1 MB/s eta 0:00:17
#    ------------ --------------------------- 8.1/26.1 MB 1.1 MB/s eta 0:00:17
#    ------------ --------------------------- 8.1/26.1 MB 1.1 MB/s eta 0:00:17
#    ------------ --------------------------- 8.4/26.1 MB 1.1 MB/s eta 0:00:17
#    ------------- -------------------------- 8.7/26.1 MB 1.1 MB/s eta 0:00:16
#    ------------- -------------------------- 8.9/26.1 MB 1.1 MB/s eta 0:00:16
#    -------------- ------------------------- 9.2/26.1 MB 1.1 MB/s eta 0:00:16
#    -------------- ------------------------- 9.4/26.1 MB 1.1 MB/s eta 0:00:16
#    -------------- ------------------------- 9.7/26.1 MB 1.1 MB/s eta 0:00:16
#    --------------- ------------------------ 10.0/26.1 MB 1.1 MB/s eta 0:00:15
#    --------------- ------------------------ 10.0/26.1 MB 1.1 MB/s eta 0:00:15
#    --------------- ------------------------ 10.2/26.1 MB 1.1 MB/s eta 0:00:15
#    ---------------- ----------------------- 10.5/26.1 MB 1.1 MB/s eta 0:00:15
#    ---------------- ----------------------- 10.7/26.1 MB 1.1 MB/s eta 0:00:15
#    ---------------- ----------------------- 11.0/26.1 MB 1.1 MB/s eta 0:00:14
#    ----------------- ---------------------- 11.3/26.1 MB 1.1 MB/s eta 0:00:14
#    ----------------- ---------------------- 11.3/26.1 MB 1.1 MB/s eta 0:00:14
#    ----------------- ---------------------- 11.5/26.1 MB 1.1 MB/s eta 0:00:14
# ...
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ----------- ----------------------------  7/24 [pyarrow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    --------------- ------------------------  9/24 [numpy]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    ---------------- ----------------------- 10/24 [narwhals]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    -------------------- ------------------- 12/24 [fonttools]
#    ------------------------- -------------- 15/24 [pydeck]
#    ------------------------- -------------- 15/24 [pydeck]
#    ------------------------- -------------- 15/24 [pydeck]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    -------------------------- ------------- 16/24 [pandas]
#    ---------------------------- ----------- 17/24 [gitdb]
#    ---------------------------- ----------- 17/24 [gitdb]
#    ------------------------------ --------- 18/24 [contourpy]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    --------------------------------- ------ 20/24 [gitpython]
#    --------------------------------- ------ 20/24 [gitpython]
#    --------------------------------- ------ 20/24 [gitpython]
#    ----------------------------------- ---- 21/24 [seaborn]
#    ----------------------------------- ---- 21/24 [seaborn]
#    ----------------------------------- ---- 21/24 [seaborn]
#    ----------------------------------- ---- 21/24 [seaborn]
#    ------------------------------------ --- 22/24 [altair]
#    ------------------------------------ --- 22/24 [altair]
#    ------------------------------------ --- 22/24 [altair]
#    ------------------------------------ --- 22/24 [altair]
#    ------------------------------------ --- 22/24 [altair]
#    ------------------------------------ --- 22/24 [altair]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    -------------------------------------- - 23/24 [streamlit]
#    ---------------------------------------- 24/24 [streamlit]
#
# Successfully installed altair-5.5.0 cachetools-6.2.0 contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.2 gitdb-4.0.12 gitpython-3.1.45 kiwisolver-1.4.9 matplotlib-3.10.6 narwhals-2.5.0 numpy-2.3.3 pandas-2.3.2 pillow-11.3.0 pyarrow-21.0.0 pydeck-0.9.1 pyparsing-3.2.3 pytz-2025.2 seaborn-0.13.2 smmap-5.0.2 streamlit-1.49.1 tenacity-9.1.2 toml-0.10.2 tzdata-2025.2 watchdog-6.0.0

# %%
# !which python
# Out:
# /c/Users/KSPC Technician1/AppData/Local/Programs/Python/Python313/python

# %%
import sys
# !{sys.executable} -m pip install pandas matplotlib seaborn streamlit
# Out:
# 'C:\Users\KSPC' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import sys
!"{sys.executable}" -m pip install pandas matplotlib seaborn streamlit numpy
# Out:
# Requirement already satisfied: pandas in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: matplotlib in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: streamlit in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (1.49.1)
# Requirement already satisfied: numpy in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.2.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.32.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.5.0)
# Requirement already satisfied: colorama in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\kspc technician1\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("metadata.csv")

# Show first 5 rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pandas as pd
#       3 # Load the dataset
# ----> 4 df = pd.read_csv("metadata.csv")
#       6 # Show first 5 rows
#       7 df.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:325, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa4 in position 11: invalid start byte

# %%
import pandas as pd

# Load dataset with explicit encoding
df = pd.read_csv("metadata.csv", encoding="latin1")

# Show first 5 rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       3 # Load dataset with explicit encoding
# ----> 4 df = pd.read_csv("metadata.csv", encoding="latin1")
#       6 # Show first 5 rows
#       7 df.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 4 fields in line 3, saw 5

# %%
df = pd.read_csv("metadata.csv", encoding="ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv("metadata.csv", encoding="ISO-8859-1")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 4 fields in line 3, saw 5

# %%
import pandas as pd

df = pd.read_csv("metadata.csv", encoding="latin1", on_bad_lines="skip", low_memory=False)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("metadata.csv", encoding="latin1", on_bad_lines="skip", low_memory=False)
#       5 df.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:239, in CParserWrapper.read(self, nrows)
#     236         data = _concatenate_chunks(chunks)
#     238     else:
# --> 239         data = self._reader.read(nrows)
#     240 except StopIteration:
#     241     if self._first_chunk:
#
# File pandas/_libs/parsers.pyx:820, in pandas._libs.parsers.TextReader.read()
#
# File pandas/_libs/parsers.pyx:914, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.

# %%
import pandas as pd

df = pd.read_csv(
    "metadata.csv",
    encoding="latin1",
    on_bad_lines="skip",
    low_memory=False,
    engine="python"   # use python engine instead of C
)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(
#       4     "metadata.csv",
#       5     encoding="latin1",
#       6     on_bad_lines="skip",
#       7     low_memory=False,
#       8     engine="python"   # use python engine instead of C
#       9 )
#      11 df.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1607, in TextFileReader.__init__(self, f, engine, **kwds)
#    1604 # miscellanea
#    1605 self._currow = 0
# -> 1607 options = self._get_options_with_defaults(engine)
#    1608 options["storage_options"] = kwds.get("storage_options", None)
#    1610 self.chunksize = options.pop("chunksize", None)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1660, in TextFileReader._get_options_with_defaults(self, engine)
#    1658             pass
#    1659         else:
# -> 1660             raise ValueError(
#    1661                 f"The {repr(argname)} option is not supported with the "
#    1662                 f"{repr(engine)} engine"
#    1663             )
#    1664 else:
#    1665     value = default
#
# ValueError: The 'low_memory' option is not supported with the 'python' engine

# %%
import pandas as pd

df = pd.read_csv(
    "metadata.csv",
    encoding="latin1",
    on_bad_lines="skip",
    engine="python"   # tolerant parser
)

df.head()
# Out:
# ¤ÆTäg¶Kÿÿÿÿÿÿÿÿ
# metadata.csvtÜHb~#¼½KÜÈ&¸o ÿ!à"#ÐôI§¦§z+S!E+u«Q¸0æîTÐIO>"äZ%0ZOÐ]Ëô¦g5Ý³
# jÕ¹ùùKæ|çIÒSUÂ½uîN£Ù±cç}>KÊ*ýK¥~½Q~]¶U¢ÿòÑo²&×~ZfþnÐ»6Þêô/ô¯<KtQk_ÅuS©¤ÁWyVoþÒd[ú´m6eUûh BåþV­ñÐí¦üKRÞd©.hxú@U³üc®þò¡.¿¬²\×x[ÿÏ¶Êý:¢ßýÛÓ®ç7åòJ­ây³Ù"¢ùb¶Z  \
# ÝnË"SÚËN¬                                        jO5Þ÷Y±öÎã´ÍÕ§ì÷CÝèªÎ½÷²¬wYCkõ¾Óiª6¾w¥Ú4óÎ+...
# æ£`â?¸P©*2ß{¯ªìgïüw^lÔ6¥ÏÎiÊ;à?¾xâ½âUxO³Ú§...  !SÈ=ûÐÿ·ÿ&â6lýY
# Lgóy´L¢p2V³Y:Ïu
# ¨h5¯¢4Ñ...
# 'kºNÆdºÌfóålnMWýÁÌ³                              Ñ±ÉwE¬r
# CrâP`ë\ßð_4Ë´
# G#½5x'oÞþöËÿ&ê%+H )0...
# É±ZÉ¾Ñ4~z´                                                                                 None
# r6:£Il÷:/ù                                                                                       None
#
#                                                      £å*]&Ë X  \
# ÝnË"SÚËN¬                                        ¢³éN1
# æ£`â?¸P©*2ß{¯ªìgïüw^lÔ6¥ÏÎiÊ;à?¾xâ½âUxO³Ú§...       None
# 'kºNÆdºÌfóålnMWýÁÌ³                                   None
# É±ZÉ¾Ñ4~z´                                         None
# r6:£Il÷:/ù                                               None
#
#                                                          ç«Ø¿¼xâ?xgE¨Ü[iÕ´®½rå%mvUy£
# ïb»\Õ[åí
# ÝnË"SÚËN¬                                        åç6«h*ÝfuMt%ÒuÓ§óÉRáñr»m
# ¢ðH%òèqGo_<µÂ¿0d...
# æ£`â?¸P©*2ß{¯ªìgïüw^lÔ6¥ÏÎiÊ;à?¾xâ½âUxO³Ú§...                                               None
# 'kºNÆdºÌfóålnMWýÁÌ³                                                                           None
# É±ZÉ¾Ñ4~z´                                                                                 None
# r6:£Il÷:/ù                                                                                       None

# %%
import pandas as pd

# Read directly from zip file
df = pd.read_csv("metadata.csv.zip", compression="zip", on_bad_lines="skip", engine="python")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 import pandas as pd
#       3 # Read directly from zip file
# ----> 4 df = pd.read_csv("metadata.csv.zip", compression="zip", on_bad_lines="skip", engine="python")
#       6 df.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:794, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     789 # ZIP Compression
#     790 elif compression == "zip":
#     791     # error: Argument 1 to "_BytesZipFile" has incompatible type
#     792     # "Union[str, BaseBuffer]"; expected "Union[Union[str, PathLike[str]],
#     793     # ReadBuffer[bytes], WriteBuffer[bytes]]"
# --> 794     handle = _BytesZipFile(
#     795         handle, ioargs.mode, **compression_args  # type: ignore[arg-type]
#     796     )
#     797     if handle.buffer.mode == "r":
#     798         handles.append(handle)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:1037, in _BytesZipFile.__init__(self, file, mode, archive_name, **kwargs)
#    1034 kwargs.setdefault("compression", zipfile.ZIP_DEFLATED)
#    1035 # error: Incompatible types in assignment (expression has type "ZipFile",
#    1036 # base class "_BufferedWriter" defined the type as "BytesIO")
# -> 1037 self.buffer: zipfile.ZipFile = zipfile.ZipFile(  # type: ignore[assignment]
#    1038     file, mode, **kwargs
#    1039 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'metadata.csv.zip'
